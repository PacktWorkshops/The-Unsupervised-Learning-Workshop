# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline
X, y = make_blobs(n_samples=1000, centers=8, n_features=2, random_state=800)

# %%
# Visualize the data
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
db = DBSCAN(eps=0.7, min_samples=10, metric='euclidean')

# %%
str(db)
# Out:
# "DBSCAN(algorithm='auto', eps=0.7, leaf_size=30, metric='euclidean',\n    metric_params=None, min_samples=10, n_jobs=None, p=None)"

# %%
num_samples = [10,19,20]
for min_num in num_samples:
    db = DBSCAN(eps=0.7, min_samples=min_num, metric='euclidean')
    plt.scatter(X[:,0], X[:,1], c=db.fit_predict(X))
    plt.title('Toy Problem with Minimum Points: ' + str(min_num))
    plt.show()

# %%
import unittest
class TestDBSCAN(unittest.TestCase):
    def test_db(self):
        db = DBSCAN(eps=0.7, min_samples=10, metric='euclidean')
        self.assertEqual(str(db),"DBSCAN(algorithm='auto', eps=0.7, leaf_size=30, metric='euclidean',\n    metric_params=None, min_samples=10, n_jobs=None, p=None)")

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestDBSCAN)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_db (__main__.TestDBSCAN) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>
