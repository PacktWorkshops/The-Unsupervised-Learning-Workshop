# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = make_blobs(n_samples=1000, centers=8, n_features=2, random_state=800)

# %%
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
methods = ['centroid', 'single', 'complete', 'average', 'weighted']

# %%
for method in methods:
    distances = linkage(X, method=method, metric="euclidean")
    clusters = fcluster(distances, 3, criterion="distance") 
    plt.title('linkage: ' + method)
    plt.scatter(X[:,0], X[:,1], c=clusters, cmap='tab20b')
    plt.show()

# %%
#  Unit Test

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.datasets import make_blobs
import unittest
class TestLinkageFcluster(unittest.TestCase):    
    def test_X_y(self):
        X2, y2 = make_blobs(n_samples=1000, centers=8, n_features=2, random_state=800)
        self.assertEqual(len(X2),len(X))
        self.assertEqual(len(y2),len(y))
        
    def test_methods(self):
        self.assertListEqual(methods,['centroid', 'single', 'complete', 'average', 'weighted'])

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestLinkageFcluster)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_X_y (__main__.TestLinkageFcluster) ... ok
# test_methods (__main__.TestLinkageFcluster) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>
