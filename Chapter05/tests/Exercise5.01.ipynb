# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    return np.exp(z) / (np.exp(z) + 1)

# %%
theta = 1
x = np.linspace(-5, 5, 100)
x
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
#         1.56565657,  1.66666667,  1.76767677,  1.86868687,  1.96969697,
#         2.07070707,  2.17171717,  2.27272727,  2.37373737,  2.47474747,
#         2.57575758,  2.67676768,  2.77777778,  2.87878788,  2.97979798,
#         3.08080808,  3.18181818,  3.28282828,  3.38383838,  3.48484848,
#         3.58585859,  3.68686869,  3.78787879,  3.88888889,  3.98989899,
#         4.09090909,  4.19191919,  4.29292929,  4.39393939,  4.49494949,
#         4.5959596 ,  4.6969697 ,  4.7979798 ,  4.8989899 ,  5.        ])

# %%
y = sigmoid(x * theta)

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

ax.plot(x, y)
ax.set_xlabel('$x$', fontsize=22)
ax.set_ylabel('$h(x\Theta)$', fontsize=22)
ax.spines['left'].set_position(('data', 0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %%
theta = 5
y_2 = sigmoid(x * theta)

# %%
theta = 0.2
y_3 = sigmoid(x * theta)

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

ax.plot(x, y, label='$\Theta=1$')
ax.plot(x, y_2, label='$\Theta=5$', linestyle=':')
ax.plot(x, y_3, label='$\Theta=0.2$', linestyle='--')
ax.set_xlabel('$x\Theta$', fontsize=22)
ax.set_ylabel('$h(x\Theta)$', fontsize=22)
ax.spines['left'].set_position(('data', 0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=22)
ax.legend(fontsize=22)
plt.show()

# %%
#  Unit Test

# %%
import unittest
class TestSigmoid(unittest.TestCase):   
    
    def test_x_len(self):
        self.assertEqual(len(x),100)
        
    def test_y_len(self):
        self.assertEqual(len(y),100)
        
    def test_theta(self):
        self.assertIn(theta,[1,5,0.2])
        
    def test_y_2_len(self):
        self.assertEqual(len(y_2),100)
        
    def test_y_3_len(self):
        self.assertEqual(len(y_3),100)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase(TestSigmoid)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_theta (__main__.TestSigmoid) ... ok
# test_x_len (__main__.TestSigmoid) ... ok
# test_y_2_len (__main__.TestSigmoid) ... ok
# test_y_3_len (__main__.TestSigmoid) ... ok
# test_y_len (__main__.TestSigmoid) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.008s
#
# OK
# <unittest.runner.TextTestResult run=5 errors=0 failures=0>
